# %%
import numpy as np
import pandas as pd

# Load dataset
food = pd.read_excel("Food data.xlsx")
food.head()
# Out:
#    order_id  customer_id            restaurant_name cuisine_type  \
# 0   1477147       337525                    Hangawi       Korean
# 1   1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2   1477070        66393                Cafe Habana      Mexican
# 3   1477334       106968  Blue Ribbon Fried Chicken     American
# 4   1478249        76942           Dirty Bird to Go     American
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              30.75         Weekend  Not Given                     25
# 1              12.08         Weekend  Not given                     25
# 2              12.23         Weekday          5                     23
# 3              29.20         Weekend          3                     25
# 4              11.59         Weekday          4                     25
#
#    delivery_time  Column1
# 0             20      NaN
# 1             23      NaN
# 2             28      NaN
# 3             15      NaN
# ...

# %%
print("Dataset Shape:")
print(food.shape)

print("Data Summary")
print(food.describe())

food.isnull().sum()
food.info()
# Out:
# Dataset Shape:
# (1898, 10)
# Data Summary
#            order_id    customer_id  cost_of_the_order  food_preparation_time  \
# count  1.898000e+03    1898.000000        1898.000000            1898.000000
# mean   1.477496e+06  171168.478398          16.498851              27.371970
# std    5.480497e+02  113698.139743           7.483812               4.632481
# min    1.476547e+06    1311.000000           4.470000              20.000000
# 25%    1.477021e+06   77787.750000          12.080000              23.000000
# 50%    1.477496e+06  128600.000000          14.140000              27.000000
# 75%    1.477970e+06  270525.000000          22.297500              31.000000
# max    1.478444e+06  405334.000000          35.410000              35.000000
#
#        delivery_time  Column1
# count    1898.000000      0.0
# mean       24.161749      NaN
# std         4.972637      NaN
# min        15.000000      NaN
# 25%        20.000000      NaN
# 50%        25.000000      NaN
# ...

# %%
# Most Ordered Cuisine
print("Most Ordered Cuisine")
print(food['cuisine_type'].value_counts())
# Out:
# Most Ordered Cuisine
# cuisine_type
# American          584
# Japanese          470
# Italian           298
# Chinese           215
# Mexican            77
# Indian             73
# Middle Eastern     49
# Mediterranean      46
# Thai               19
# French             18
# Southern           17
# Korean             13
# Spanish            12
# Vietnamese          7
# Name: count, dtype: int64

# %%
#Average Cost by Day
food.groupby('day_of_the_week')['cost_of_the_order'].mean()
# Out:
# day_of_the_week
# Weekday    16.311188
# Weekend    16.574833
# Name: cost_of_the_order, dtype: float64

# %%
#Delivery Time by Day
df.groupby('day_of_the_week')['delivery_time'].mean()
# Out:
# day_of_the_week
# Weekday    28.340037
# Weekend    22.470022
# Name: delivery_time, dtype: float64

# %%
# Orders by Day
print("Orders by Day")
print(food['day_of_the_week'].value_counts())
# Out:
# Orders by Day
# day_of_the_week
# Weekend    1351
# Weekday     547
# Name: count, dtype: int64

# %%
#Avearge Delivery Time
avg_delivery = np.mean(df['delivery_time'])
print("Average Delivery Time")
print(avg_delivery)
# Out:
# Average Delivery Time:
# 24.161749209694417

# %%
# Average Food Preparation Time
avg_prep = np.mean(food['food_preparation_time'])
print("\nAverage Food Preparation Time")
print(avg_prep)
# Out:
# Average Food Preparation Time:
# 27.371970495258168

# %%
print("Top 10 Restaurants")
print(food['restaurant_name'].value_counts().head(10))
# Out:
# Top 10 Restaurants
# restaurant_name
# Shake Shack                      219
# The Meatball Shop                132
# Blue Ribbon Sushi                119
# Blue Ribbon Fried Chicken         96
# Parm                              68
# RedFarm Broadway                  59
# RedFarm Hudson                    55
# TAO                               49
# Han Dynasty                       46
# Blue Ribbon Sushi Bar & Grill     44
# Name: count, dtype: int64

# %%
# Customer Ratings
print("\nRatings Count:")
print(food['rating'].value_counts())
# Out:
# Ratings Count:
# rating
# Not given    735
# 5            588
# 4            386
# 3            188
# Not Given      1
# Name: count, dtype: int64

# %%
#FINAL INSIGHTS:

#Key Insights
#Weekend orders were higher than weekday orders, showing more demand during weekends.
#American cuisine was the most popular cuisine ordered.
#Most customers gave high ratings, indicating customer satisfaction.
#Shake Shack had the highest number of orders.
#Weekend delivery time was faster compared to weekdays.

#Conclusion

#From the analysis, customer demand is stronger during weekends, and popular cuisines attract more orders. 
#Restaurants with efficient delivery and good customer service receive better ratings and more patronage.

#Recommendation
#Increase staff and resources during weekends.
#Offer promotions during weekdays.
#Improve delivery efficiency.
#Encourage more customers to leave ratings.
